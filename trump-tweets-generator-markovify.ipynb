# %% [markdown]
# # Donald Trump Tweet Simulator
# Just a silly and entertaining project.  Uses the lovely [markovify](https://github.com/jsvine/markovify) library and Tweets from [here](http://www.trumptwitterarchive.com).

# %%
import pandas as pd
tweets = pd.read_json('./tweets.json')
tweets.head()
# Out:
#                source                                               text  \
# 0  Twitter for iPhone  Never has the press been more inaccurate, unfa...
# 1  Twitter for iPhone  In a letter to me sent by Kim Jong Un, he stat...
# 2  Twitter for iPhone  ....also a small apology for testing the short...
# 3  Twitter for iPhone  Maggie Haberman of the Failing @nytimes report...
# 4  Twitter for iPhone  RT @GOPChairwoman: Thanks to the unhinged mob ...
#
#                  created_at  retweet_count  favorite_count  is_retweet  \
# 0 2019-08-10 12:07:34+00:00          27228          107352         0.0
# 1 2019-08-10 11:58:57+00:00          14803           72358         0.0
# 2 2019-08-10 11:58:57+00:00          13566           73492         0.0
# 3 2019-08-10 11:40:48+00:00          22489           87269         0.0
# 4 2019-08-09 20:36:30+00:00          22031               0         1.0
#
#                 id_str
# 0  1160160760179372032
# 1  1160158591518674944
# 2  1160158592483418112
# ...

# %%
# Retain all non-retweet entries (value is 0/1 as a float).
tweets = tweets[tweets.is_retweet < 1.0]

# %%
# Some values may be treated as floats, so cast all to string.
tweets['text'] = tweets.text.astype('str')

# Remove all URLs.
#url_regex = r"""https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9]+\.[^\s]{2,}|www\.[a-zA-Z0-9]+\.[^\s]{2,}"""
#tweets['text'] = tweets.text.str.replace(url_regex, '')

# Fix `&amp;`.
tweets['text'] = tweets.text.str.replace(r'&amp;', '&')

# Replace inverted quotes.
tweets['text'] = tweets.text.str.replace('“', '"')
tweets['text'] = tweets.text.str.replace('”', '"')

# Replace strange hyphens.
tweets['text'] = tweets.text.str.replace('–', '-')
tweets['text'] = tweets.text.str.replace('—', '-')

# Replace strange apostrophes.
tweets['text'] = tweets.text.str.replace('’', "'")
tweets['text'] = tweets.text.str.replace('‘', "'")
tweets['text'] = tweets.text.str.replace('\x92', "'")

# Replace latin space.
tweets['text'] = tweets.text.str.replace('\xa0', ' ')
# Zero width space.
tweets['text'] = tweets.text.str.replace('\u200b', ' ')

# l2r and r2l marks.
tweets['text'] = tweets.text.str.replace('\u200e', '')
tweets['text'] = tweets.text.str.replace('\u200f', '')

# Fix bad unicode.
tweets['text'] = tweets.text.str.replace('\U0010fc00', '')

# %%
# Join all lines for the model.
tweets_text = '\n'.join(tweets.text.values)

# %%
# Make a Text model using markovify.
import markovify
text_model = markovify.Text(tweets_text)

# %%
for i in range(10):
    print('{}: {}'.format(i, text_model.make_short_sentence(280)))
# Out:
# 0: .@RNC report was written by @GreggJarrett and @JudgeJeanine Pirro.
# 1: There is no way my friend @Schwarzenegger who is fluent in Russian.
# 2: Don't negate your own newspaper--- without the Wall, people are killing the Harvey Weinstein story, is now being paid to shut down our military, not do the heavy lifting for China's pollution while they were legit, they would be rich as hell!
# 3: Will be interviewed by @MariaBartiromo on Sunday on NBC Watch CNN tonight as Piers and Omarosa.
# 4: End the Democrats will have a plan that would not be allowed to respond?
# 5: Read more: https://t.co/sYZ4PzzxxW https://t.co/gi0qGe6ukX I have millions more votes/hundreds more dels than Cruz or Rand Paul.
# 6: #ElectionNight #MAGA🇺🇸 https://t.co/HfuJeRZbod Still time to take action so that this will stop the massive unreported crisis now unfolding -- or are they now own it.Republicans should keep the Sikorsky Helicopter Plant in Coatesville, Pennsylvania, open and fair elections.
# ...

# %% [markdown]
# Here are a few bangers I had come out!  My apologies if any of thesed are close to real tweets... it's hard to tell these days.
#
# * `The opinion of yourself, is a scam!`
# * `This really backfired - love you Missouri!`
# * `My shirts, ties and shirts at the debate.`
# * `We cannot allow our Great Nation.`
# * `Thx Snowden is a producer.`
#
# Try to generate your own!
